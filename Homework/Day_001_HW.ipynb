# %% [markdown]
# 作業一：
#
# 我選擇 World Happiness Report。
#
# 1. 想研究各種因素是如何影響幸福指數，我認為幸福指數可以作為教育改革的參考以及影響政策走向。
# 2. 來自Gallup World Poll，各個因素的分數透過問卷訪問並加權而成。
# 3. 屬於結構化的資料，有各種數值與表格化。
# 4. 目前想到是利用迴歸模型跑相關係數，但希望有更精準的方式。
#
# 作業二:
#
# 1. 問題：短途旅客多於長途旅客，但長途旅客的利潤較高，目前的長途旅客多為商務旅客，來回往返公司與高鐵或機場，要如何提升商務旅客的載客率?
# 2. 像一般的計程車一樣，紀錄每個旅客的上下車地點與時間，找出商務旅客的共通點，以及透過APP預約的資料來分析他們的乘車時間與地點。
# 3. 結構化資料：上下車時間(車程時間)、上下車地點
#    非結構資料：路線圖
# 4. 透過眾數找出最常搭乘的時間，可以在那時間多派計程車駐點，甚至找出特定公司搭乘的頻率最高，可與該公司談固定合作。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_squared_error(y,y_hat):
    """
    請完成這個 Function 後往下執行
    """
    MSE = sum((y-y_hat)**2)/len(y)
    return MSE

MSE = mean_squared_error

# %%
def mean_absolute_error(y,y_hat):
    MAE = sum(abs(y-y_hat)) / len(y)
    return MAE

MAE = mean_absolute_error

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 261.753
# The Mean absolute error is 12.999
